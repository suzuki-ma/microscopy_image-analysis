# %%
from PIL import Image
import cv2
import numpy as np

# 画像ファイルのパスを指定してください
image_path = 'testB1.png'
img = Image.open(image_path).convert("L")
img = np.array(img).astype(np.uint8)
equalized = cv2.equalizeHist(img)
equalized
# Out:
# array([[240, 162, 162, ..., 152, 157, 137],
#        [ 67,  42,  72, ...,  72,  53,  39],
#        [ 42,  39, 102, ...,  36,  62,  62],
#        ...,
#        [241, 223, 231, ..., 248, 240, 239],
#        [246, 202, 206, ..., 245, 237, 235],
#        [248, 233, 217, ..., 246, 239, 235]], dtype=uint8)
