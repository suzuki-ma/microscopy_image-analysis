# %%
from PIL import Image
import cv2
import numpy as np

# 画像ファイルのパスを指定してください
image_path = 'testB1.png'
img = Image.open(image_path)
img = np.array(img)
filtered = cv2.medianBlur(img, 9)
filtered
# Out:
# array([[[115, 115, 115],
#         [115, 115, 115],
#         [113, 113, 113],
#         ...,
#         [110, 110, 110],
#         [110, 110, 110],
#         [110, 110, 110]],
#
#        [[108, 108, 108],
#         [104, 104, 104],
#         [104, 104, 104],
#         ...,
#         [104, 104, 104],
#         [104, 104, 104],
#         [102, 102, 102]],
#
#        [[103, 103, 103],
#         [ 97,  97,  97],
#         [ 96,  96,  96],
#         ...,
#         [ 99,  99,  99],
#         [ 99,  99,  99],
#         [ 98,  98,  98]],
#
#        ...,
#
#        [[130, 130, 130],
#         [130, 130, 130],
#         [128, 128, 128],
#         ...,
#         [139, 139, 139],
#         [138, 138, 138],
#         [138, 138, 138]],
#
#        [[134, 134, 134],
#         [133, 133, 133],
#         [129, 129, 129],
#         ...,
#         [139, 139, 139],
#         [138, 138, 138],
#         [137, 137, 137]],
#
#        [[134, 134, 134],
#         [134, 134, 134],
#         [130, 130, 130],
# ...
